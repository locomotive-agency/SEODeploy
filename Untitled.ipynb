# %%
# !pip install dictdiffer

# %%
from dictdiffer import diff, patch, swap, revert

# %%
timing1 =  {
      "connectStart": 91,
      "navigationStart": 0,
      "loadEventEnd": 1680,
      "domLoading": 261,
      "secureConnectionStart": 111,
      "fetchStart": 0,
      "domContentLoadedEventStart": 757,
      "responseStart": 252,
      "responseEnd": 254,
      "domInteractive": 712,
      "domainLookupEnd": 91,
      "redirectStart": 0,
      "requestStart": 230,
      "unloadEventEnd": 0,
      "unloadEventStart": 0,
      "domComplete": 1664,
      "domainLookupStart": 7,
      "loadEventStart": 1664,
      "domContentLoadedEventEnd": 761,
      "redirectEnd": 0,
      "connectEnd": 230
    }


timing2 =  {
      "connectStart": 121,
      "navigationStart": 0,
      "loadEventEnd": 1680,
      "domLoading": 261,
      "secureConnectionStart": 111,
      "fetchStart": 0,
      "domContentLoadedEventStart": 757,
      "responseStart": 252,
      "responseEnd": 254,
      "domInteractive": 834,
      "domainLookupEnd": 91,
      "redirectStart": 0,
      "requestStart": 230,
      "unloadEventEnd": 0,
      "unloadEventStart": 0,
      "domComplete": 1664,
      "domainLookupStart": 7,
      "loadEventStart": 1664,
      "domContentLoadedEventEnd": 761,
      "redirectEnd": 0,
      "connectEnd": 230
    }

results = diff(timing1, timing2)
list(results)
# Out:
# [('change', 'connectStart', (91, 121)),
#  ('change', 'domInteractive', (712, 834))]

# %%
h1_1 = [
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[1]/h2",
      "content": "TECHNICAL SEO"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[2]/h2",
      "content": "CONTENT"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[3]/h2",
      "content": "LOCAL SEO"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[4]/h2",
      "content": "LINK BUILDING"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[5]/h2",
      "content": "PAY-PER-CLICK"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[6]/h2",
      "content": "IMPLEMENTATION"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[3]/div/h2",
      "content": "BEST SEO AGENCY AWARD"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[4]/div/h2",
      "content": "WE ARE MOZ RECOMMENDED."
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[6]/div/div/div[1]/h2",
      "content": "Connect with us."
    }
  ]

h1_2 = [
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[1]/h2",
      "content": "TECHNICAL SEO"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[2]/h2",
      "content": "CONTENT"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[3]/h2",
      "content": "CONTACT US"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[4]/h2",
      "content": "LOCAL SEO"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[5]/h2",
      "content": "Link Building"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[6]/h2",
      "content": "PAY-PER-CLICK"
    },
    {
      "xpath": "/html/body/div[1]/div/main/div[2]/div/div/div[7]/h2",
      "content": "IMPLEMENTATION"
    },

    {
      "xpath": "/html/body/div[1]/div/main/div[6]/div/div/div[1]/h2",
      "content": "Connect with us"
    }
  ]

# %%
from dictdiffer import diff, patch, swap, revert


def l2d(l1,l2):
    d1 = {i['xpath']:i['content'] for i in l1 if i['xpath'] and len(i['xpath'])}
    d2 = {i['xpath']:i['content'] for i in l2 if i['xpath'] and len(i['xpath'])}
    return d1,d2

def item_change(diffs):
    
    results = []
    
    for diff in diffs:
        ctype, element, details = diff

        if ctype == "change":
            results.append({'type': ctype, 'item': element, 'before': details[0], 'after': details[1]})
        else:
            for item in details:
                results.append({'type': ctype, 'item': item[0], 'content': item[1]})
    
    return results

def diff_changes(d1, d2):
    d1, d2 = l2d(d1,d2)
    results = diff(d1, d2)
    return item_change(results)

diff_changes(h1_1, h1_2)
# Out:
# [{'type': 'change',
#   'item': '/html/body/div[1]/div/main/div[2]/div/div/div[3]/h2',
#   'before': 'LOCAL SEO',
#   'after': 'CONTACT US'},
#  {'type': 'change',
#   'item': '/html/body/div[1]/div/main/div[2]/div/div/div[4]/h2',
#   'before': 'LINK BUILDING',
#   'after': 'LOCAL SEO'},
#  {'type': 'change',
#   'item': '/html/body/div[1]/div/main/div[2]/div/div/div[5]/h2',
#   'before': 'PAY-PER-CLICK',
#   'after': 'Link Building'},
#  {'type': 'change',
#   'item': '/html/body/div[1]/div/main/div[2]/div/div/div[6]/h2',
#   'before': 'IMPLEMENTATION',
#   'after': 'PAY-PER-CLICK'},
#  {'type': 'change',
#   'item': '/html/body/div[1]/div/main/div[6]/div/div/div[1]/h2',
#   'before': 'Connect with us.',
#   'after': 'Connect with us'},
#  {'type': 'add',
#   'item': '/html/body/div[1]/div/main/div[2]/div/div/div[7]/h2',
#   'content': 'IMPLEMENTATION'},
#  {'type': 'remove',
#   'item': '/html/body/div[1]/div/main/div[3]/div/h2',
#   'content': 'BEST SEO AGENCY AWARD'},
# ...

# %%
item_change(diff(timing1, timing2))
# Out:
# [{'type': 'change', 'item': 'connectStart', 'before': 91, 'after': 121},
#  {'type': 'change', 'item': 'domInteractive', 'before': 712, 'after': 834}]

# %%
typ, element, changes = results[3]

# %%
print(typ)
print(element)
print(changes)
# Out:
# change
# /html/body/div[1]/div/main/div[2]/div/div/div[6]/h2
# ('IMPLEMENTATION', 'PAY-PER-CLICK')

# %%
from deepdiff import DeepDiff

d1, d2 = l2d(h1_1, h1_2)

results = DeepDiff(d1, d2)
results
# Out:
# {'dictionary_item_added': [root['/html/body/div[1]/div/main/div[2]/div/div/div[7]/h2']],
#  'values_changed': {"root['/html/body/div[1]/div/main/div[2]/div/div/div[6]/h2']": {'new_value': 'PAY-PER-CLICK',
#    'old_value': 'IMPLEMENTATION'},
#   "root['/html/body/div[1]/div/main/div[2]/div/div/div[5]/h2']": {'new_value': 'Link Building',
#    'old_value': 'PAY-PER-CLICK'},
#   "root['/html/body/div[1]/div/main/div[2]/div/div/div[3]/h2']": {'new_value': 'CONTACT US',
#    'old_value': 'LOCAL SEO'},
#   "root['/html/body/div[1]/div/main/div[2]/div/div/div[4]/h2']": {'new_value': 'LOCAL SEO',
#    'old_value': 'LINK BUILDING'},
#   "root['/html/body/div[1]/div/main/div[6]/div/div/div[1]/h2']": {'new_value': 'Connect with us',
#    'old_value': 'Connect with us.'}}}

# %%
st = {'set_item'}
st
# Out:
# {'set_item'}

# %%
''.join(st)
# Out:
# 'set_item'

# %%
from dictdiffer import diff

def compare_lists_of_objects(l1, l2, element='element', content='content', item=None, tolerance=None):

    # Changes list to dict based on given key_attr and content_attr values.
    d1, d2 = l2d(l1, l2, element, content)

    return compare_objects(d1, d2, item=item, tolerance=tolerance)


def compare_objects(d1, d2, item=None, tolerance=None):
    
    tolerance = tolerance or 0
    
    if isinstance(d1, list) and isinstance(d2, list):
        otype = 'set'
        d1, d2 = set(d1), set(d2)
    elif isinstance(d1, set) and isinstance(d1, set):
        otype = 'set'
        pass
    elif isinstance(d1, dict) and isinstance(d1, dict):
        otype = 'dict'
    else:
        raise AttributeError('Unsupported object types provided.  Supports `list`, `set`, or `dict`')
    
    
    diffs = diff(d1, d2, tolerance=tolerance)

    return format_diffs(diffs, otype, item)


def format_diffs(diffs, otype, item):

    results = []

    for diff in diffs:
        ctype, location, details = diff
        
        new = not location
        
        '''
        ('add',
          '',
          [('/html/head[1]', ['LOCOMOTIVE - Enterprise Technical SEO Agency'])])]
        '''
        
        if ctype == "change":
            element = ".".join([str(i) for i in location]) if isinstance(location, list) else location
            item = item or location[0] if isinstance(location, list) else location
            results.append({'type': ctype, 'item': item, 'element': element, 'before': details[0], 'after': details[1]})
        else:
            for detail in details:
                
                content = detail[1]
                
                if otype == 'dict' and new:
                    element = '.'.join(detail[0]) if isinstance(detail[0], list) else detail[0]
                    item = item or detail[0]
                    content = detail[1][0]
                elif otype == 'dict':
                    elements = ['.'.join([str(i) for i in location]) if isinstance(location, list) else str(location)]
                    elements += ['.'.join(detail[0]) if isinstance(detail[0], list) else str(detail[0])]
                    element = '.'.join(elements)
                    item = item or elements[0]
                    content = detail[1]
                else:
                    item = ''.join(detail[1])
                    element = None
                    content = None
                    
                results.append({'type': ctype, 'item': item, 'element': element, 'content': content})

    return results


def l2d(l1, l2, key_attr, content_attr):
    """Turns a list of dicts into a dict based on given key attribute and content attribute.
        parameters:
            l1: <list> first list of dicts.
            l2: <list> second list of dicts.
            key_attr: <str> dict key to be used as key for new dict.
            content_attr: <str> or <list> dict key(s) to be used as value for new dict.
    """
    d1, d2 = {}, {}
    
    def adder(k, c, o):
        if k in o:
            o[k] += [c]
        else:
            o[k] = [c]
        
    if isinstance(content_attr, str):
        _ = [adder(i[key_attr], i[content_attr], d1) for i in l1 if key_attr in i and len(i[key_attr])]
        _ = [adder(i[key_attr], i[content_attr], d2) for i in l2 if key_attr in i and len(i[key_attr])]
    elif isinstance(content_attr, list):
        _ = [adder(i[key_attr], {i[v] for v in content_attr}, d1) for i in l1 if i[key_attr] and len(i[key_attr])]
        _ = [adder(i[key_attr], {i[v] for v in content_attr}, d2) for i in l2 if i[key_attr] and len(i[key_attr])]
    else:
        raise NotImplementedError("`content_attr` can only be of type `str` or `list`")


    return d1,d2

# %%
content1 =  [
        {
            "element": "canonical",
            "content": "https://locomotive.agency/category/google/"
        },
        {
            "element": "title",
            "content": "Google Archives - LOCOMOTIVE\u00ae"
        },
        {
            "element": "h1",
            "content": "Google"
        },
        {
            "element": "h2",
            "content": "Quick Tips that Can Make Your Outreach Process Successful"
        },
        {
            "element": "h2",
            "content": "The General Data Protection Regulation (GDPR) and Google Analytics Data Retention Update"
        },
        {
            "element": "h2",
            "content": "Benefits & Reasonings for Posting in Google My Business"
        },
        {
            "element": "meta_robots",
            "content": "max-snippet:-1, max-image-preview:large, max-video-preview:-1"
        },
        {
            "element": "open_graph_title",
            "content": "Google Archives - LOCOMOTIVE\u00ae"
        },
        {
            "element": "open_graph_type",
            "content": "object"
        },
        {
            "element": "open_graph_url",
            "content": "https://locomotive.agency/category/google/"
        },
        {
            "element": "twitter_card",
            "content": "summary_large_image"
        },
        {
            "element": "twitter_title",
            "content": "Google Archives - LOCOMOTIVE\u00ae"
        },
        {
            "element": "google_analytics",
            "content": "UA-29401593-5"
        },
        {
            "element": "hotjar",
            "content": "1716204"
        },
        {
            "element": "google_tag_manager",
            "content": "GTM-TCVSKL3"
        }
    ]


content2 =  [
        {
            "element": "canonical",
            "content": "https://locomotive.agency/category/google/"
        },
        {
            "element": "title",
            "content": "Google Archives - LOCOMOTIVE\u00ae"
        },
        {
            "element": "h1",
            "content": "Google"
        },
        {
            "element": "h2",
            "content": "Quick Tips that Can Make Your Outreach Process Successful"
        },
        {
            "element": "h2",
            "content": "The General Data Protection Regulation (GDPR) and Google Analytics Data Retention Update"
        },
        {
            "element": "h2",
            "content": "Benefits & Reasonings for Posting in Google My Business"
        },
        {
            "element": "h2",
            "content": "Why you should love us."
        },
        {
            "element": "meta_robots",
            "content": "max-snippet:-1, max-image-preview:large, max-video-preview:-1"
        },
        {
            "element": "open_graph_title",
            "content": "Google Archives - LOCOMOTIVE\u00ae"
        },
        {
            "element": "open_graph_type",
            "content": "object"
        },
        {
            "element": "open_graph_url",
            "content": "https://locomotive.agency/category/google/"
        },
        {
            "element": "twitter_card",
            "content": "summary_large_image"
        },
        {
            "element": "twitter_title",
            "content": "Google Archives - LOCOMOTIVE\u00ae"
        },
        {
            "element": "google_analytics",
            "content": "UA-29433593-5"
        },
        {
            "element": "hotjar",
            "content": "1716204"
        },
        {
            "element": "google_tag_manager",
            "content": "GTM-TCVSKL3"
        }
    ]


def format_content(items):
    result = []

compare_lists_of_objects(content1, content2)
# Out:
# [{'type': 'add',
#   'item': 'h2',
#   'element': 'h2.3',
#   'content': 'Why you should love us.'},
#  {'type': 'change',
#   'item': 'h2',
#   'element': 'google_analytics.0',
#   'before': 'UA-29401593-5',
#   'after': 'UA-29433593-5'}]

# %%
title1 = [{
    "element": "/html/head",
    "content": "LOCOMOTIVE\u00ae - Enterprise Technical SEO Agency"
  },
  {
    "element": "/html/head_remove",
    "content": "LOCOMOTIVE\u00ae - Enterprise Technical SEO Agency"
  }]

title2 = [{
    "element": "/html/head",
    "content": "LOCOMOTIVE - Enterprise Technical SEO Agency"
  },
  {
    "element": "/html/head[1]",
    "content": "LOCOMOTIVE - Enterprise Technical SEO Agency"
  }]

compare_lists_of_objects(title1, title2, item='title', tolerance=None)
# Out:
# [{'type': 'change',
#   'item': 'title',
#   'element': '/html/head.0',
#   'before': 'LOCOMOTIVE® - Enterprise Technical SEO Agency',
#   'after': 'LOCOMOTIVE - Enterprise Technical SEO Agency'},
#  {'type': 'add',
#   'item': 'title',
#   'element': '/html/head[1]',
#   'content': 'LOCOMOTIVE - Enterprise Technical SEO Agency'},
#  {'type': 'remove',
#   'item': 'title',
#   'element': '/html/head_remove',
#   'content': 'LOCOMOTIVE® - Enterprise Technical SEO Agency'}]

# %%
l1 = {}
l2 = []

type(l1) == type(l2)
# Out:
# False

# %%
d = {'a':{'b':1,'c':2},'b':3}

d.get('a.b', None)

# %%
get
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-345-ccd3d78f393b> in <module>
# ----> 1 get
#
# NameError: name 'get' is not defined

# %%
# list of Dicts.

H21 = [
  {
    "element": "/html/body/div[1]/div/main/div[2]/div/div/div[1]",
    "content": "TECHNICAL SEO"
  },
  {
    "element": "/html/body/div[1]/div/main/div[2]/div/div/div[2]",
    "content": "CONTENT"
  }]
    
H22 = [
  {
    "element": "/html/body/div[1]/div/main/div[2]/div/div/div[1]",
    "content": "TECHNICAL SEOS"
  },
  {
    "element": "/html/body/div[1]/div/main/div[2]/div/div/div[2]",
    "content": "CONTENT"
  },
  {
    "element": "/html/body/div[1]/div/main/div[2]/div/div/div[3]",
    "content": "ABOUT"
  }]

compare_lists_of_objects(H21, H22, item='h2', tolerance=None)
# Out:
# [{'type': 'change',
#   'item': 'h2',
#   'element': '/html/body/div[1]/div/main/div[2]/div/div/div[1].0',
#   'before': 'TECHNICAL SEO',
#   'after': 'TECHNICAL SEOS'},
#  {'type': 'add',
#   'item': 'h2',
#   'element': '/html/body/div[1]/div/main/div[2]/div/div/div[3]',
#   'content': 'ABOUT'}]

# %%
# If a list is given.

oi1 =  [
"marginal/set",
"images/title_attribute",
"images/alt_attribute",
"meta_description/missing"
]


oi2 =  [
"images/alt_attribute",
"images/title_attribute",
"images/title_attribute",
"meta_description/missing",
"schema/missing"
]


compare_objects(oi1, oi2, tolerance=None)
# Out:
# [{'type': 'add', 'item': 'schema/missing', 'element': None, 'content': None},
#  {'type': 'remove', 'item': 'marginal/set', 'element': None, 'content': None}]

# %%
# If a list of dictionaries is given.

img1 = [
  {
    "element": "/html/body/nav/div/div/a/img",
    "content": {
      "src": "https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-small.png",
      "alt": "LOCOMOTIVE Agency"
    }
  },
  {
    "element": "/html/body/header/div/a/img",
    "content": {
      "src": "https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-small.png",
      "alt": "LOCOMOTIVE Agency"
    }
  }]


img2 = [
  {
    "element": "/html/body/nav/div/div/a/img",
    "content": {
      "src": "https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-small.png",
      "alt": "LOCOMOTIVE Agency"
    }
  },
  {
    "element": "/html/body/header/div/a/img",
    "content": {
      "src": "https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-large.png",
      "alt": "LOCOMOTIVE Agency"
    }
  },
  {
    "element": "/html/body/header/div[2]/a/img",
    "content": {
      "src": "https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-contact.png",
      "alt": "Contact"
    }
  }]

compare_lists_of_objects(img1, img2, item='images', tolerance=None)
# Out:
# [{'type': 'change',
#   'item': 'images',
#   'element': '/html/body/header/div/a/img.0.src',
#   'before': 'https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-small.png',
#   'after': 'https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-large.png'},
#  {'type': 'add',
#   'item': 'images',
#   'element': '/html/body/header/div[2]/a/img',
#   'content': {'src': 'https://mk0locomotiveagoonti.kinstacdn.com/wp-content/uploads/2019/05/locomotive-logo-contact.png',
#    'alt': 'Contact'}}]

# %%
timing1 =  {
      "connectStart": 91,
      "navigationStart": 0,
      "loadEventEnd": 1680,
      "domLoading": 261,
      "secureConnectionStart": 111,
      "fetchStart": 0,
      "domContentLoadedEventStart": 757,
      "responseStart": 252,
      "responseEnd": 254,
      "domInteractive": 712,
      "domainLookupEnd": 91,
      "redirectStart": 0,
      "requestStart": 230,
      "unloadEventEnd": 0,
      "unloadEventStart": 0,
      "domComplete": 1664,
      "domainLookupStart": 7,
      "loadEventStart": 1664,
      "domContentLoadedEventEnd": 761,
      "redirectEnd": 0,
      "connectEnd": 230
    }


timing2 =  {
      "connectStart": 121,
      "navigationStart": 0,
      "loadEventEnd": 1680,
      "domLoading": 261,
      "secureConnectionStart": 111,
      "fetchStart": 0,
      "domContentLoadedEventStart": 757,
      "responseStart": 252,
      "responseEnd": 254,
      "domInteractive": 834,
      "domainLookupEnd": 91,
      "redirectStart": 0,
      "requestStart": 230,
      "unloadEventEnd": 0,
      "unloadEventStart": 0,
      "domComplete": 1664,
      "domainLookupStart": 7,
      "loadEventStart": 1664,
      "domContentLoadedEventEnd": 761,
      "redirectEnd": 0,
      "connectEnd": 230
    }

results = compare_objects(timing1, timing2, tolerance=0.2)
list(results)
# Out:
# [{'type': 'change',
#   'item': 'connectStart',
#   'element': 'connectStart',
#   'before': 91,
#   'after': 121}]

# %%
schema1 = [
        {
            "@context": "http://schema.org/",
            "@type": "CollectionPage",
            "headline": "Google Category",
            "description": "",
            "url": "/category/google/",
            "sameAs": [],
            "hasPart": [
                {
                    "@context": "http://schema.org/",
                    "@type": "NewsArticle",
                    "mainEntityOfPage": {
                        "@type": "WebPage",
                        "@id": "https://locomotive.agency/google/quick-tips-that-can-make-your-outreach-process-successful/"
                    },
                    "url": "https://locomotive.agency/google/quick-tips-that-can-make-your-outreach-process-successful/",
                    "headline": "Quick Tips that Can Make Your Outreach Process...",
                    "datePublished": "2018-09-21T07:14:48-04:00",
                    "dateModified": "2018-09-21T07:14:48-04:00",
                    "publisher": {
                        "@type": "Organization",
                        "@id": "https://locomotive.agency/#organization",
                        "name": "LOCOMOTIVE\u00ae",
                        "logo": {
                            "@type": "ImageObject",
                            "url": "",
                            "width": 600,
                            "height": 60
                        }
                    },
                    "articleSection": "Google",
                    "description": "Writing emails for outreach for link building is key to getting the attention of your readers. On this post we want to share several templates and details in the outreach process that we\u2019ve tried and have seen their effectiveness. Building Contact Lists: Avoid using generic emails, since those usually",
                    "author": {
                        "@type": "Person",
                        "name": "Robert Padgett Cooper",
                        "url": "https://locomotive.agency/author/robert/",
                        "image": {
                            "@type": "ImageObject",
                            "url": "https://secure.gravatar.com/avatar/02d41950f46b1d28de4941d83a66712c?s=96&d=mm&r=g",
                            "height": 96,
                            "width": 96
                        },
                        "sameAs": [
                            "http://www.locomotiveagency.com"
                        ]
                    }
                },
                {
                    "@context": "http://schema.org/",
                    "@type": "NewsArticle",
                    "mainEntityOfPage": {
                        "@type": "WebPage",
                        "@id": "https://locomotive.agency/google/the-general-data-protection-regulation-gdpr-and-google-analytics-data-retention-update-2/"
                    },
                    "url": "https://locomotive.agency/google/the-general-data-protection-regulation-gdpr-and-google-analytics-data-retention-update-2/",
                    "headline": "The General Data Protection Regulation (GDPR) and Google Analytics Data Retention...",
                    "datePublished": "2018-05-17T15:01:58-04:00",
                    "dateModified": "2018-05-17T15:01:58-04:00",
                    "publisher": {
                        "@type": "Organization",
                        "@id": "https://locomotive.agency/#organization",
                        "name": "LOCOMOTIVE\u00ae",
                        "logo": {
                            "@type": "ImageObject",
                            "url": "",
                            "width": 600,
                            "height": 60
                        }
                    },
                    "image": {
                        "@type": "ImageObject",
                        "url": "https://adaptpartners.com/wp-content/uploads/2018/05/GAemail.png",
                        "width": 696,
                        "height": "599"
                    },
                    "articleSection": "Google",
                    "description": "We gathered helpful information to help you understand what the GDPR is and how it affects you. Also with this new regulation, Google Analytics has been preparing to meet with these requirements that will take place May 25, 2018. Ian Lurie stated that \u201cif you don\u2019t want block traffic",
                    "author": {
                        "@type": "Person",
                        "name": "Robert Padgett Cooper",
                        "url": "https://locomotive.agency/author/robert/",
                        "image": {
                            "@type": "ImageObject",
                            "url": "https://secure.gravatar.com/avatar/02d41950f46b1d28de4941d83a66712c?s=96&d=mm&r=g",
                            "height": 96,
                            "width": 96
                        },
                        "sameAs": [
                            "http://www.locomotiveagency.com"
                        ]
                    }
                },
                {
                    "@context": "http://schema.org/",
                    "@type": "NewsArticle",
                    "mainEntityOfPage": {
                        "@type": "WebPage",
                        "@id": "https://locomotive.agency/google/benefits-reasonings-for-google-my-business/"
                    },
                    "url": "https://locomotive.agency/google/benefits-reasonings-for-google-my-business/",
                    "headline": "Benefits & Reasonings for Posting in Google My...",
                    "datePublished": "2018-04-25T08:09:19-04:00",
                    "dateModified": "2018-04-25T08:09:19-04:00",
                    "publisher": {
                        "@type": "Organization",
                        "@id": "https://locomotive.agency/#organization",
                        "name": "LOCOMOTIVE\u00ae",
                        "logo": {
                            "@type": "ImageObject",
                            "url": "",
                            "width": 600,
                            "height": 60
                        }
                    },
                    "image": {
                        "@type": "ImageObject",
                        "url": "https://adaptpartners.com/wp-content/uploads/2018/04/mybusiness-menu.jpg",
                        "width": 696,
                        "height": "441"
                    },
                    "articleSection": "Google",
                    "description": "1). What are Google Posts Posting through Google My Business is a feature that allows businesses to create content that will show up directly in search and maps. These articles are meant to be timely and are meant to share recent business updates, promotions, sales, events, etc. These articles",
                    "author": {
                        "@type": "Person",
                        "name": "Robert Padgett Cooper",
                        "url": "https://locomotive.agency/author/robert/",
                        "image": {
                            "@type": "ImageObject",
                            "url": "https://secure.gravatar.com/avatar/02d41950f46b1d28de4941d83a66712c?s=96&d=mm&r=g",
                            "height": 96,
                            "width": 96
                        },
                        "sameAs": [
                            "http://www.locomotiveagency.com"
                        ]
                    }
                }
            ]
        },
        {
            "@context": "http://schema.org",
            "@type": "BreadcrumbList",
            "itemListElement": [
                {
                    "@type": "ListItem",
                    "position": 1,
                    "item": {
                        "@id": "https://locomotive.agency",
                        "name": "Home"
                    }
                },
                {
                    "@type": "ListItem",
                    "position": 2,
                    "item": {
                        "@id": "/category/google/",
                        "name": "Google"
                    }
                }
            ]
        }
    ]

schema2 = [
        {
            "@context": "http://schema.org/",
            "@type": "CollectionPage",
            "headline": "Google Category",
            "description": "",
            "url": "/category/google/",
            "sameAs": [],
            "hasPart": [
                {
                    "@context": "http://schema.org/",
                    "@type": "NewsArticle",
                    "mainEntityOfPage": {
                        "@type": "WebPage",
                        "@id": "https://locomotive.agency/google/quick-tips-that-can-make-your-outreach-process-successful/"
                    },
                    "url": "https://locomotive.agency/google/quick-tips-that-can-make-your-outreach-process-successful/",
                    "headline": "Quick Tips that Can Make Your Outreach Process...",
                    "datePublished": "2018-09-21T07:14:48-04:00",
                    "dateModified": "2018-09-21T07:14:48-04:00",
                    "publisher": {
                        "@type": "Organization",
                        "@id": "https://locomotive.agency/#organization",
                        "name": "LOCOMOTIVE\u00ae",
                        "logo": {
                            "@type": "ImageObject",
                            "url": "",
                            "width": 600,
                            "height": 60
                        }
                    },
                    "articleSection": "Gooooogle",
                    "description": "Writing emails for outreach for link building is key to getting the attention of your readers. On this post we want to share several templates and details in the outreach process that we\u2019ve tried and have seen their effectiveness. Building Contact Lists: Avoid using generic emails, since those usually",
                    "author": {
                        "@type": "Person",
                        "name": "Robert Padgett Cooper",
                        "url": "https://locomotive.agency/author/robert/",
                        "image": {
                            "@type": "ImageObject",
                            "url": "https://secure.gravatar.com/avatar/02d41950f46b1d28de4941d83a66712c?s=96&d=mm&r=g",
                            "height": 96,
                            "width": 96
                        },
                        "sameAs": [
                            "http://www.locomotiveagency.com"
                        ]
                    }
                },
                {
                    "@context": "http://schema.org/",
                    "@type": "NewsArticle",
                    "mainEntityOfPage": {
                        "@type": "WebPage",
                        "@id": "https://locomotive.agency/google/the-general-data-protection-regulation-gdpr-and-google-analytics-data-retention-update-2/"
                    },
                    "url": "https://locomotive.agency/google/the-general-data-protection-regulation-gdpr-and-google-analytics-data-retention-update-2/",
                    "headline": "The General Data Protection Regulation (GDPR) and Google Analytics Data Retention...",
                    "publisher": {
                        "@type": "Organization",
                        "@id": "https://locomotive.agency/#organization",
                        "name": "LOCOMOTIVE\u00ae",
                        "logo": {
                            "@type": "ImageObject",
                            "url": "",
                            "width": 600,
                            "height": 60
                        }
                    },
                    "image": {
                        "@type": "ImageObject",
                        "url": "https://adaptpartners.com/wp-content/uploads/2018/05/GAemail.png",
                        "width": 696,
                        "height": "599"
                    },
                    "articleSection": "Google",
                    "description": "We gathered helpful information to help you understand what the GDPR is and how it affects you. Also with this new regulation, Google Analytics has been preparing to meet with these requirements that will take place May 25, 2018. Ian Lurie stated that \u201cif you don\u2019t want block traffic",
                    "author": {
                        "@type": "Person",
                        "name": "Robert Padgett Cooper",
                        "url": "https://locomotive.agency/author/robert/",
                        "image": {
                            "@type": "ImageObject",
                            "url": "https://secure.gravatar.com/avatar/02d41950f46b1d28de4941d83a66712c?s=96&d=mm&r=g",
                            "height": 96,
                            "width": 96
                        },
                        "sameAs": [
                            "http://www.locomotiveagency.com"
                        ]
                    }
                },
                {
                    "@context": "http://schema.org/",
                    "@type": "NewsArticle",
                    "mainEntityOfPage": {
                        "@type": "WebPage",
                        "@id": "https://locomotive.agency/google/benefits-reasonings-for-google-my-business/"
                    },
                    "url": "https://locomotive.agency/google/benefits-reasonings-for-google-my-business/",
                    "headline": "Benefits & Reasonings for Posting in Google My...",
                    "datePublished": "2018-04-25T08:09:19-04:00",
                    "dateModified": "2018-04-25T08:09:19-04:00",
                    "publisher": {
                        "@type": "Organization",
                        "@id": "https://locomotive.agency/#organization",
                        "name": "LOCOMOTIVE\u00ae",
                        "logo": {
                            "@type": "ImageObject",
                            "url": "",
                            "width": 1200,
                            "height": 60
                        }
                    },
                    "image": {
                        "@type": "ImageObject",
                        "url": "https://adaptpartners.com/wp-content/uploads/2018/04/mybusiness-menu.jpg",
                        "width": 696,
                        "height": "441"
                    },
                    "articleSection": "Google",
                    "description": "1). What are Google Posts Posting through Google My Business is a feature that allows businesses to create content that will show up directly in search and maps. These articles are meant to be timely and are meant to share recent business updates, promotions, sales, events, etc. These articles",
                    "author": {
                        "@type": "Person",
                        "name": "Robert Padgett Cooper",
                        "url": "https://locomotive.agency/author/robert/",
                        "image": {
                            "@type": "ImageObject",
                            "url": "https://secure.gravatar.com/avatar/02d41950f46b1d28de4941d83a66712c?s=96&d=mm&r=g",
                            "height": 96,
                            "width": 96
                        },
                        "sameAs": [
                            "http://www.locomotiveagency.com"
                        ]
                    }
                }
            ]
        },
        {
            "@context": "http://schema.org",
            "@type": "BreadcrumbList",
            "itemListElement": [
                {
                    "@type": "ListItem",
                    "position": 1,
                    "item": {
                        "@id": "https://locomotive.agency",
                        "name": "Home"
                    }
                },
                {
                    "@type": "ListItem",
                    "position": 2,
                    "item": {
                        "@id": "/category/google/",
                        "name": "Google"
                    }
                },
                {
                    "@type": "ListItem",
                    "position": 3,
                    "item": {
                        "@id": "/category/google/fun/",
                        "name": "Google"
                    }
                }
            ]
        }
    ]

schema1 = [{'element': i["@type"], 'content':i} for i in schema1]
schema2 = [{'element': i["@type"], 'content':i} for i in schema2]
compare_lists_of_objects(schema1, schema2, item='schema', tolerance=None)
# Out:
# [{'type': 'change',
#   'item': 'schema',
#   'element': 'CollectionPage.0.hasPart.0.articleSection',
#   'before': 'Google',
#   'after': 'Gooooogle'},
#  {'type': 'remove',
#   'item': 'schema',
#   'element': 'CollectionPage.0.hasPart.1.datePublished',
#   'content': '2018-05-17T15:01:58-04:00'},
#  {'type': 'remove',
#   'item': 'schema',
#   'element': 'CollectionPage.0.hasPart.1.dateModified',
#   'content': '2018-05-17T15:01:58-04:00'},
#  {'type': 'change',
#   'item': 'schema',
#   'element': 'CollectionPage.0.hasPart.2.publisher.logo.width',
#   'before': 600,
#   'after': 1200},
#  {'type': 'add',
#   'item': 'schema',
#   'element': 'BreadcrumbList.0.itemListElement.2',
#   'content': {'@type': 'ListItem',
#    'position': 3,
#    'item': {'@id': '/category/google/fun/', 'name': 'Google'}}}]

# %%
l = [1,2,3]
len(l)
# Out:
# 3

# %%
example = {
    "content": {
      "canonical": [
        {
          "element": "/html/head/link[2]",
          "content": "https://gofishdigital.com/"
        }
      ],
      "robots": [
        {
          "element": "/html/head/meta[5]",
          "content": "max-snippet:-1, max-image-preview:large, max-video-preview:-1"
        }
      ],
      "title": [
        {
          "element": "/html/head/title",
          "content": "Go Fish Digital - Online Reputation Management and Digital Marketing Agency."
        }
      ],
      "meta_description": [
        {
          "element": "/html/head/meta[4]",
          "content": "Go Fish Digital is a Washington DC based Digital Marketing Agency specializing in Online Reputation Management, Search Engine Optimization, Website Development, Social Media Marketing and more."
        }
      ],
      "h1": [
        {
          "element": "/html/body/div[1]/div/header/article/h1",
          "content": "Word of mouth is digital - lead the conversation"
        }
      ],
      "h2": [
        {
          "element": "/html/body/div[3]/h2",
          "content": "Our Work"
        },
        {
          "element": "/html/body/section[2]/h2",
          "content": "Blog"
        },
        {
          "element": "/html/body/section[3]/div/h2",
          "content": "Contact us"
        }
      ],
      "links": [
        {
          "element": "/html/body/div[1]/nav/div/a",
          "content": {
            "href": "https://gofishdigital.com/#",
            "text": "Toggle Menu",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[1]/a",
          "content": {
            "href": "https://gofishdigital.com/about-us/",
            "text": "About Us",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/a",
          "content": {
            "href": "https://gofishdigital.com/services/",
            "text": "Services",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[1]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-optimization/",
            "text": "Search Engine Optimization",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[2]/a",
          "content": {
            "href": "https://gofishdigital.com/content-marketing/",
            "text": "Content Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[3]/a",
          "content": {
            "href": "https://gofishdigital.com/online-reputation-management/",
            "text": "Online Reputation Management",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[4]/a",
          "content": {
            "href": "https://gofishdigital.com/influencer-marketing/",
            "text": "Influencer Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[5]/a",
          "content": {
            "href": "https://gofishdigital.com/website-design-and-development/",
            "text": "Web Design & Development",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[6]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-marketing/",
            "text": "Search Engine Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[2]/ul/li[7]/a",
          "content": {
            "href": "https://gofishdigital.com/conversion-rate-optimization/",
            "text": "Conversion Rate Optimization",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[3]/a",
          "content": {
            "href": "https://gofishdigital.com/careers/",
            "text": "Careers",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[4]/a",
          "content": {
            "href": "https://gofishdigital.com/blog/",
            "text": "Blog",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/div/ul/li[5]/a",
          "content": {
            "href": "https://gofishdigital.com/contact-us/",
            "text": "Contact",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/a[1]",
          "content": {
            "href": "https://gofishdigital.com/",
            "text": "GoFish Digital",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/a[2]",
          "content": {
            "href": "https://gofishdigital.com/",
            "text": "GoFish Digital",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[1]/a",
          "content": {
            "href": "https://gofishdigital.com/about-us/",
            "text": "About Us",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/a",
          "content": {
            "href": "https://gofishdigital.com/services/",
            "text": "Services",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[1]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-optimization/",
            "text": "Search Engine Optimization",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[2]/a",
          "content": {
            "href": "https://gofishdigital.com/content-marketing/",
            "text": "Content Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[3]/a",
          "content": {
            "href": "https://gofishdigital.com/online-reputation-management/",
            "text": "Online Reputation Management",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[4]/a",
          "content": {
            "href": "https://gofishdigital.com/influencer-marketing/",
            "text": "Influencer Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[5]/a",
          "content": {
            "href": "https://gofishdigital.com/website-design-and-development/",
            "text": "Web Design & Development",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[6]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-marketing/",
            "text": "Search Engine Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[2]/ul/li[7]/a",
          "content": {
            "href": "https://gofishdigital.com/conversion-rate-optimization/",
            "text": "Conversion Rate Optimization",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[3]/a",
          "content": {
            "href": "https://gofishdigital.com/careers/",
            "text": "Careers",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[4]/a",
          "content": {
            "href": "https://gofishdigital.com/blog/",
            "text": "Blog",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/nav/ul/li[5]/a",
          "content": {
            "href": "https://gofishdigital.com/contact-us/",
            "text": "Contact",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/p/a",
          "content": {
            "href": "https://gofishdigital.com/services/",
            "text": "Get Started",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[1]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-optimization/",
            "text": "Learn More",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[2]/a",
          "content": {
            "href": "https://gofishdigital.com/online-reputation-management/",
            "text": "Learn More",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[3]/a",
          "content": {
            "href": "https://gofishdigital.com/website-design-and-development/",
            "text": "Learn More",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[4]/a",
          "content": {
            "href": "https://gofishdigital.com/content-marketing/",
            "text": "Learn More",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[5]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-marketing/",
            "text": "Learn More",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[6]/a",
          "content": {
            "href": "https://gofishdigital.com/conversion-rate-optimization/",
            "text": "Learn More",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[1]/article/a",
          "content": {
            "href": "https://gofishdigital.com/about-us/",
            "text": "Meet the team >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/p/a[1]",
          "content": {
            "href": "https://gofishdigital.com/#",
            "text": "\u25c4 Previous Case Study",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/p/a[2]",
          "content": {
            "href": "https://gofishdigital.com/#",
            "text": "Next Case Study \u25ba",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[1]/div[2]/article/p[1]/span/a",
          "content": {
            "href": "https://www.caprelo.com/",
            "text": "CapRelo",
            "rel": "noopener"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[1]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/olympics-campaign-garners-international-coverage-caprelo/#how-we-did-it",
            "text": "Launch Project",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[1]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[2]/div[2]/article/p[1]/span/a",
          "content": {
            "href": "https://simpletexting.com/",
            "text": "SimpleTexting",
            "rel": "noopener"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[2]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/large-gains-traffic-leads-sms-marketing-software/#how-we-did-it",
            "text": "Launch Project",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[2]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[3]/div[2]/article/p[1]/a",
          "content": {
            "href": "https://versusreviews.com/",
            "text": "Versus Reviews",
            "rel": "noopener"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[3]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/versus-reviews/#how-we-did-it",
            "text": "Launch Project",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[3]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[4]/div[2]/article/p[1]/a",
          "content": {
            "href": "https://bellaellaboutique.com/",
            "text": "Bella Ella Boutique",
            "rel": "noopener"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[4]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/clothing-retailer-doubles-website-traffic/#how-we-did-it",
            "text": "Launch Project",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[4]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[5]/div[2]/article/p[1]/a",
          "content": {
            "href": "https://www.brilliantearth.com/",
            "text": "Brilliant Earth",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[5]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/brilliant-earth-reaches-millions-through-viral-video/#how-we-did-it",
            "text": "Launch Project ",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[5]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[6]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/online-trading-academy-smart-investment-seo/#how-we-did-it",
            "text": "Launch Project",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[6]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[7]/div[2]/article/p[3]/a",
          "content": {
            "href": "https://gofishdigital.com/case-study/top-google-rankings-dc-luxury-apartments-96-occupancy-first-year/#how-we-did-it",
            "text": "Launch Project",
            "rel": ""
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[7]/div[2]/p[2]/a",
          "content": {
            "href": "https://gofishdigital.com/case-studies/",
            "text": "View All Case Studies",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[2]/div/div/div[1]/div/a",
          "content": {
            "href": "https://gofishdigital.com/native-application-vertical-search-engine/",
            "text": "Read On >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[2]/div/div/div[2]/div/a",
          "content": {
            "href": "https://gofishdigital.com/handoff-pitch-to-team-member/",
            "text": "Read On >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[2]/div/div/div[3]/div/a",
          "content": {
            "href": "https://gofishdigital.com/common-link-building-questions/",
            "text": "Read On >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[2]/div/div/div[4]/div/a",
          "content": {
            "href": "https://gofishdigital.com/classify-offensive-content/",
            "text": "Read On >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[2]/div/div/div[5]/div/a",
          "content": {
            "href": "https://gofishdigital.com/google-alerts-monitoring-media-mentions-for-free/",
            "text": "Read On >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[2]/div/div/div[6]/div/a",
          "content": {
            "href": "https://gofishdigital.com/clear-concise-copy-during-covid19/",
            "text": "Read On >",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[3]/div/div/article/div/div/div/p[2]/a",
          "content": {
            "href": "mailto:info@gofishdigital.com",
            "text": "info@gofishdigital.com",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[3]/div/div/article/div/div/div/h4[1]/a",
          "content": {
            "href": "https://gofishdigital.com/dc/",
            "text": "Virginia, Maryland, DC",
            "rel": ""
          }
        },
        {
          "element": "/html/body/section[3]/div/div/article/div/div/div/h4[2]/a",
          "content": {
            "href": "https://gofishdigital.com/raleigh/",
            "text": "Raleigh",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/a",
          "content": {
            "href": "https://gofishdigital.com/",
            "text": "GoFishDigital",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[1]/a",
          "content": {
            "href": "https://gofishdigital.com/about-us/",
            "text": "About Us",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/a",
          "content": {
            "href": "https://gofishdigital.com/services/",
            "text": "Services",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[1]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-optimization/",
            "text": "Search Engine Optimization",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[2]/a",
          "content": {
            "href": "https://gofishdigital.com/content-marketing/",
            "text": "Content Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[3]/a",
          "content": {
            "href": "https://gofishdigital.com/online-reputation-management/",
            "text": "Online Reputation Management",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[4]/a",
          "content": {
            "href": "https://gofishdigital.com/influencer-marketing/",
            "text": "Influencer Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[5]/a",
          "content": {
            "href": "https://gofishdigital.com/website-design-and-development/",
            "text": "Web Design & Development",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[6]/a",
          "content": {
            "href": "https://gofishdigital.com/search-engine-marketing/",
            "text": "Search Engine Marketing",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[2]/ul/li[7]/a",
          "content": {
            "href": "https://gofishdigital.com/conversion-rate-optimization/",
            "text": "Conversion Rate Optimization",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[3]/a",
          "content": {
            "href": "https://gofishdigital.com/careers/",
            "text": "Careers",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[4]/a",
          "content": {
            "href": "https://gofishdigital.com/blog/",
            "text": "Blog",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/ul/li[5]/a",
          "content": {
            "href": "https://gofishdigital.com/contact-us/",
            "text": "Contact",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/p[1]/a[1]",
          "content": {
            "href": "https://www.facebook.com/GoFishDigital",
            "text": "Facebook",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/p[1]/a[2]",
          "content": {
            "href": "http://twitter.com/gofishdigital",
            "text": "Twitter",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/p[1]/a[3]",
          "content": {
            "href": "https://www.linkedin.com/company/go-fish-digital",
            "text": "LinkedIn",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/p[1]/a[4]",
          "content": {
            "href": "https://plus.google.com/+Gofishdigital/posts",
            "text": "GooglePlus",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/p[1]/a[5]",
          "content": {
            "href": "mailto:info@gofishdigital.com",
            "text": "Email",
            "rel": ""
          }
        },
        {
          "element": "/html/body/footer/div[2]/a",
          "content": {
            "href": "http://gofishdigital.com/privacy-policy/",
            "text": "Privacy Policy",
            "rel": ""
          }
        }
      ],
      "images": [
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/airbnb-horizontal-125.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[2]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/ford-125.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[3]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/header-client-logo-1.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[4]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/header-client-logo-2.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[5]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/header-client-logo-3.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[6]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/symantec_LOGO.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[7]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/monster-energy-logo.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[1]/div/header/article/div[3]/ul/li[8]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/header-client-logo-8.png",
            "alt": ""
          }
        },
        {
          "element": "/html/body/div[2]/section/div[1]/figure/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/themes/ngfd/assets/build/img/icons/nhmi-seo.png",
            "alt": "Search Engine Optimization icon"
          }
        },
        {
          "element": "/html/body/div[2]/section/div[2]/figure/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/themes/ngfd/assets/build/img/icons/nhmi-orm.png",
            "alt": "Online Reputation Management icon"
          }
        },
        {
          "element": "/html/body/div[2]/section/div[3]/figure/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/themes/ngfd/assets/build/img/icons/nhmi-web-design.png",
            "alt": "Web Design & Development icon"
          }
        },
        {
          "element": "/html/body/div[2]/section/div[4]/figure/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/themes/ngfd/assets/build/img/icons/nhmi-content.png",
            "alt": "Content marketing icon"
          }
        },
        {
          "element": "/html/body/div[2]/section/div[5]/figure/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/themes/ngfd/assets/build/img/icons/SEM-icn.png",
            "alt": "Search engine marketing icon"
          }
        },
        {
          "element": "/html/body/div[2]/section/div[6]/figure/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/themes/ngfd/assets/build/img/icons/CRO-icn.png",
            "alt": "Conversion rate optimization icon"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[1]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/summaryCapRelo.jpg",
            "alt": "tldr brief summary thumbnail"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[2]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/gofishstudy3.jpeg",
            "alt": "tldr brief summary thumbnail"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[3]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/summaryCocktails.jpg",
            "alt": "tldr brief summary thumbnail"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[4]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/summaryImage.jpg",
            "alt": "tldr brief summary thumbnail"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[5]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/BrilliantEarth_CaseStudy-02.png",
            "alt": "tldr brief summary thumbnail"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[6]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/OTA-homepage-and-single-v1-.jpg",
            "alt": "tldr brief summary thumbnail"
          }
        },
        {
          "element": "/html/body/div[3]/div/div/div[7]/div[1]/img",
          "content": {
            "src": "https://gofishdigital.com/wp-content/uploads/PVN-homepage-and-single-v1-.jpg",
            "alt": "tldr brief summary thumbnail"
          }
        }
      ],
      "schema": [
        {
          "element": "/html/head/script[10]",
          "content": {
            "@context": "https://schema.org",
            "@graph": [
              {
                "@type": "Organization",
                "@id": "https://gofishdigital.com/#organization",
                "name": "Go Fish Digital",
                "url": "https://gofishdigital.com/",
                "sameAs": [
                  "https://www.facebook.com/GoFishDigital/",
                  "https://www.linkedin.com/company/go-fish-digital",
                  "https://www.youtube.com/user/GoFishDigital",
                  "https://www.pinterest.com/gofishdigital/",
                  "https://twitter.com/GoFishDigital"
                ],
                "logo": {
                  "@type": "ImageObject",
                  "@id": "https://gofishdigital.com/#logo",
                  "url": "https://gofishdigital.com/wp-content/uploads/gfd-regular.png",
                  "width": 411,
                  "height": 247,
                  "caption": "Go Fish Digital"
                },
                "image": {
                  "@id": "https://gofishdigital.com/#logo"
                }
              },
              {
                "@type": "WebSite",
                "@id": "https://gofishdigital.com/#website",
                "url": "https://gofishdigital.com/",
                "name": "Go Fish Digital",
                "publisher": {
                  "@id": "https://gofishdigital.com/#organization"
                },
                "potentialAction": {
                  "@type": "SearchAction",
                  "target": "https://gofishdigital.com/?s={search_term_string}",
                  "query-input": "required name=search_term_string"
                }
              },
              {
                "@type": "CollectionPage",
                "@id": "https://gofishdigital.com/#webpage",
                "url": "https://gofishdigital.com/",
                "inLanguage": "en-US",
                "name": "Go Fish Digital - Online Reputation Management and Digital Marketing Agency.",
                "isPartOf": {
                  "@id": "https://gofishdigital.com/#website"
                },
                "about": {
                  "@id": "https://gofishdigital.com/#organization"
                },
                "description": "Go Fish Digital is a Washington DC based Digital Marketing Agency specializing in Online Reputation Management, Search Engine Optimization, Website Development, Social Media Marketing and more."
              }
            ]
          }
        }
      ]
    },
    "performance": {
      "nodes": 1466,
      "resources": 81,
      "layout_duration": 0.16,
      "recalc_style_duration": 0.2,
      "script_duration": 0.28,
      "v8_compile_duration": 0.05,
      "task_duration": 1.31,
      "task_other_duration": 0.43,
      "thread_time": 1.36,
      "jd_heap_used_size": 4116552,
      "js_heap_total_size": 5697536,
      "time_to_first_byte": 337,
      "first_paint": 3478.8,
      "first_contentful_paint": 3478.8,
      "largest_contentful_paint": 22304.19,
      "time_to_interactive": 8941,
      "dom_content_loaded": 8941,
      "dom_complete": 33741,
      "cumulative_layout_shift": 0.0
    },
    "coverage": {
      "summary": {
        "total_unused": 1274478,
        "total_bytes": 1274478,
        "unused_pc": 1274478
      },
      "css": {
        "total_unused": 571597,
        "total_bytes": 571597,
        "unused_pc": 571597
      },
      "js": {
        "total_unused": 702881,
        "total_bytes": 702881,
        "unused_pc": 702881
      }
    }
  }

# %%
exclusions = {
  "content": {
    "canonical": False,
    "robots": False,
    "title": False,
    "meta_description": False,
    "h1": False,
    "h2": False,
    "links": False,
    "images": False,
    "schema": False
  },
  "performance": {
    "nodes": False,
    "resources": False,
    "layout_duration": False,
    "recalc_style_duration": False,
    "script_duration": False,
    "v8_compile_duration": False,
    "task_duration": False,
    "task_other_duration": False,
    "thread_time": False,
    "jd_heap_used_size": False,
    "js_heap_total_size": False,
    "time_to_first_byte": False,
    "first_paint": False,
    "first_contentful_paint": False,
    "largest_contentful_paint": False,
    "time_to_interactive": False,
    "dom_content_loaded": False,
    "dom_complete": False,
    "cumulative_layout_shift": False
  },
  "coverage": {
    "summary": {
      "total_unused": False,
      "total_bytes": False,
      "unused_pc": False
    },
    "css": {
      "total_unused": False,
      "total_bytes": False,
      "unused_pc": False
    },
    "js": {
      "total_unused": False,
      "total_bytes": False,
      "unused_pc": False
    }
  }
}

# %%
float(2)
# Out:
# 2.0
